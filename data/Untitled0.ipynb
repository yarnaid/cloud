# %%
import pandas as pd

# %%
df = pd.read_excel('./PC50107584.xlsx')

# %%
res = list()
df_t = df[['QOP26a Like', u'Unnamed: 2', ]].dropna().T
for r in df_t:
    if not df_t[r].iloc[0].isupper():
        res.append({
            'text': df_t[r].iloc[0],
            'size': df_t[r].iloc[1],
        })

# %%
import json

# %%
with open('sample.json', 'w') as f:
    json.dump(res, f)
