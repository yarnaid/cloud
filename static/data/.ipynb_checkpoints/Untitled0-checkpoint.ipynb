# %%
import pandas as pd

# %%
df = pd.read_excel('./PC50107584.xlsx')

# %%
df.iloc[:]
# Out:
#    Question:                                        QOP26a Like Unnamed: 2  \
# 0       Code                              Text (local language)        NaN
# 1        NaN                                                NaN   Effectif
# 2        NaN                                        PERSONNAGES          8
# 3        100                                           La femme          8
# 4        NaN                                                NaN        NaN
# 5        NaN                                    LE DEMAQUILLAGE          7
# 6        200                     Le démaquillage / le nettoyage          3
# 7        201                Les effets du produit / le résultat          4
# 8        NaN                                                NaN        NaN
# 9        NaN                                         DIVERS PUB         27
# 10       300                                         La musique         13
# 11       301                                       Les couleurs          6
# 12       302  La présentation du produit / explications / in...          9
# 13       303                                        La voix off          3
# 14       NaN                                                NaN        NaN
# 15       NaN                                  BENEFICES PRODUIT         37
# 16       400                                    Produit  3 en 1          5
# 17       401                                  Produit tout en 1         13
# 18       402                              Efficace / efficacité          4
# 19       403                                         Démaquille          8
# 20       404                                    Nettoie la peau          3
# 21       405                                             Rapide          6
# 22       406              Simple / facile / pratique à utiliser          9
# 23       407  Aime le produit (toutes autres références posi...          8
# 24       NaN                                                NaN        NaN
# 25       NaN                                         SENSATIONS          8
# 26       500                                 La douceur / douce          6
# 27       501                                             Pureté          3
# 28       NaN                                                NaN        NaN
# 29       NaN                                   RELATIF A LA PUB         40
# 30       700                       Claire / facile a comprendre          5
# 31       701                                Simple / simplicité          4
# 32       702                                             Humour          6
# 33       703                            Aime la durée de la pub          4
# 34       704                        Tout / l'ensemble de la pub         13
# 35       705   Aime la pub (toutes autres références positives)         13
# 36       NaN                                                NaN        NaN
# 37       599                                             Autres          5
# 38       600                                       Rien / N.S.P          0
#
#                      Unnamed: 3              Unnamed: 4
# 0                           NaN                     NaN
# 1   % de l'effectif total (150)  % des répondants (107)
# 2                    0.05333333              0.07476636
# 3                    0.05333333              0.07476636
# 4                           NaN                     NaN
# 5                    0.04666667              0.06542056
# 6                          0.02              0.02803738
# 7                    0.02666667              0.03738318
# 8                           NaN                     NaN
# 9                          0.18               0.2523364
# 10                   0.08666667               0.1214953
# 11                         0.04              0.05607477
# 12                         0.06              0.08411215
# 13                         0.02              0.02803738
# 14                          NaN                     NaN
# 15                    0.2466667               0.3457944
# 16                   0.03333333              0.04672897
# 17                   0.08666667               0.1214953
# 18                   0.02666667              0.03738318
# 19                   0.05333333              0.07476636
# 20                         0.02              0.02803738
# 21                         0.04              0.05607477
# 22                         0.06              0.08411215
# 23                   0.05333333              0.07476636
# 24                          NaN                     NaN
# 25                   0.05333333              0.07476636
# 26                         0.04              0.05607477
# 27                         0.02              0.02803738
# 28                          NaN                     NaN
# 29                    0.2666667               0.3738318
# 30                   0.03333333              0.04672897
# 31                   0.02666667              0.03738318
# 32                         0.04              0.05607477
# 33                   0.02666667              0.03738318
# 34                   0.08666667               0.1214953
# 35                   0.08666667               0.1214953
# 36                          NaN                     NaN
# 37                   0.03333333              0.04672897
# 38                            0                       0

# %%
id = 0
root = {
    'id': id,
    'name': 'root',
    'children': list()
}
current_root = root
parent = root
clusters = dict()
nodes = list()
cluster = None
for row in df.iterrows():
    code = row[1][0]
    question = row[1][1]
    effective = row[1][2]
    tot = row[1][3]
    repond = row[1][4]
    try:
        if not pd.isnull(effective) and not pd.isnull(question):
            if not question.isupper() and not pd.isnull(code):
                node = {
                    'id': id,
                    'question': question,
                    'code': code,
                    'effecif': effective,
                    'total': tot,
                    'repondants': repond,
                    'cluster': cluster,
                }
                nodes.append(node)
            elif question.isupper() and pd.isnull(code):
                node = {
                    'id': id,
                    'question': question,
    #                 'code': code,
                    'effecif': effective,
                    'total': tot,
                    'repondants': repond,
#                     'children': list()
                }
                cluster = question
                clusters[question] = node
    except Exception as e:
        print id, code, question, effective, tot, repond
        raise e
    id += 1

# %%
import json

# %%
with open('sample.json', 'w') as f:
    json.dump({'clusters':clusters, 'nodes':nodes}, f)
